# %% [markdown]
# <a href="https://colab.research.google.com/github/nhs-pycom/coding-club-IntroPython-2/blob/main/IntroPython_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**The NHSX Analytics Unit introduction to Python Session 2** *
#
#
# **Note*: Content adapted from the General Assembly Programming in Python and the Data Camp Introduction to Python courses.

# %% [markdown]
# # **5. Introduction to control flow**:
#
# Control flow is what keeps programs from doing the same thing every single time. It tells programs what to do based on different conditions.

# %% [markdown]
# ![Untitled-1.png](data:image/png;base64,...)

# %% [markdown]
# *Expression:* Any valid piece of code that evaluates to something. A non-code based example of an example would be opening the door, and asking the question "is it snowing" The answer to question is either True (yes) or False (No).

# %% [markdown]
# ![Untitled-2.png](data:image/png;base64,...)

# %% [markdown]
# This flowchart highlights two key players of program flow: conditionals and loops. If the answer to the question is False (No). The follwoing statement occurs "It is not snowing, then we will leave the house". This is called a *conditional*.

# %% [markdown]
# ![Untitled-3.png](data:image/png;base64,...)

# %% [markdown]
# Onther hand if the answer to the question "is it snowing?" is True (Yes), it is snowing, we'll watch another hour of TV and check again later. This will keep on occuring until we can finally answer, "No, it's not snowing.", and in that case "we will leave the house".
#
# *In sum, a program’s **control flow** directs the order of execution of the statements in a program.* This allows a program  to skip over some statements, execute a series of statements repetitively, or choose between alternate sets of statements to execute.

# %% [markdown]
# # **6. Comparison operators and statements:**
#
# In Python, comparison operators compare the values on either sides of them and decide the relation among them. They are also called relational operators.

# %% [markdown]
# To tell a computer how to "decide" what to do, **comparison statements** are used. Comparison statements always boil down to a single boolean value: `True` or `False`. Remember that booleans (`bools`) are one of the four key data types in Python and represent logical values. `bools` can only be `True` or `False`.
#
# To write comparison statements in programming *comparison operators* are used. A list of comparison operators are listed below:
#
# |Operator |Functionality |Example |
# |-|-|-|
# |`>`|Greater than| 5 > 2 |
# |`>=`|Greater than or equal to|5 >= 5|
# |`<`|Less than|2 < 200|
# |`<=`|Less than or equal to|1 <= 72|
# |`==`|Tests if the left and right sides have equal values|5 == 5|
# |`!=`|Tests if the left and right sides have unequal values|3 != 5|

# %%
#Comparison operators in action.
a = 17
b = 5
c = 'hello'

print(5 > 2)
print(5 < 2)
print(14 <= 14)
print(7 == 8)
print(a != b)
print(c == 'hello')

# %%
#Task 16: Create your own comparison statements, make one yield the bool 'False' and the other the bool 'True'.

# %% [markdown]
# While using python to compute a comparison can be important, its not very meaningful when used in isolation. Who needs a computer program to tell them that 100 > 4?
#
# The real power of comparisons in python lies in their use in conditional statements to control *what*, *when*, and *how* things happen in a python based program.

# %% [markdown]
# # **7. Conditional statements in python:**
#
# In a Python program, the `if` function allows for the evaluation of a conditional statement. It allows for the conditional execution of a statement or group of statements based on the value of an expression.

# %% [markdown]
# Every `if` statement must begin the line with `if`, followed by any expression, followed by a colon, then one or more indented lines of code:
#
#
# ![Untitled-4.png](data:image/png;base64,...)
#
# The indented lines of code are evulated only if the expression (converted to a `bool`) is `True`. You can think of this as, "`if` the expression is `True`, then evaluate the indented code."

# %%
#If statement in action
chance_of_rain = 0.7
if chance_of_rain < 0.9:
   print("wear a raincoat")

# %%
#Task 17: Create your own if comparison statements, comparing the variables "a" and "b" defined above. If the statment is true have it output the variable d, set to the bool True.

# %% [markdown]
# **Combining Conditional Statements:**
#
# Conditional statements are a powerful tool, but they can be made to be even more powerful, by combining one or more conditional statements using *logical operators*.
#
# By combining conditional statements, you are asking the computer to evaluate more than one condition at the same time.
#
# *For examples:*
#
# 1.   If it's going to be lower than 10ºC **and** raining, wear a raincoat.
# 2.   If it's going to be higher than 10ºC **and** raining, bring an umbrella.
# 3.   If it's going to be lower than 10ºC **or** windy, wear a sweater.
#
# There are three logical operators in python, they are listed below:
#
# |Logical Operator |Functionality |Example |
# |-|-|-|
# |`and`|	Evaluates to `true` if **both** statements are `true`|(`x > 10 and x < 20`)|
# |`or`|	Evaluates to `true` if **one** of the statements is `true`|(`x > 10 and x < 20`)|
# |`not`|	Evaluates to `true` if the result is **false** |`not (x > 10 and x < 20)`|

# %%
#Combining conditional statements in action:
e = 10
f = 14


if (e and f) < 15:
  print("Good math skills")

if (e or f) < 11:
  print("Good math skills")

if not (e and f < 7):
   print("Good math skills")

# %%
#Task 18: Create your own if combinded comparison statement using the already defined "chance_of_rain" variable and another to be defined variable "chance_of_wind". Output the string "stay at home".

# %% [markdown]
# **The else condition in if statements:**
#
# The else condition when using if statments allows for one block of code to be evaluated if the expression is `True` and another block of code if it's `False`. The syntax of an if-else statment is shown below:
#
# ![Untitled-5.png](data:image/png;base64,...)

# %%
#If-else statement in action (reminder: chance_of_rain = 0.7):

if (chance_of_rain > 0.6):        
   print("wear a raincoat")  
else:
   print("wear a cardigan")

# %%
#Task 19: To the code you wrote in Task 18 add an else statment which outputs the string "go outside". Change the comparison operator to make the conditional statement false.

# %% [markdown]
# **The elif condition in if statements:**
#
# If you need a conditional to check for more than two possibilities, you can add more comparisons to create an if ... else if ... else chain.This is called an elif statement.
#
# elif statements tell Python, "If something is true, do this. If not, check the next condition in the chain (etc.)
#
# The first conditional statment that is true is executed, while the rest of the chain is skipped entirely. The syntax of an elif chain is shown below:
#
# ![Untitled-6.png](data:image/png;base64,...)

# %% [markdown]
# `elif` statements always have one `if`, as many `elifs` as you want, and zero to one `else`. Remember that in an `elif` chain, once the computer finds a true condition, it skips the rest of the chain.

# %%
#elif chain at work: 

grade = 42

if grade >= 90:
    print("You got an A.")
elif grade >= 80:
    print("You got a B.")
elif grade >= 70:
    print("You got a C.")
elif grade >= 60:
    print("You got a D.")
else:
    print("You failed, sorry.")

# %%
#Task 20: Using the variables chance_of_rain and chance_of_wind create an elif chain with at least one combined comparison statement. Set you else statment to output "watch netflix in bed" (reminder: chance_of_rain = 0.7):

# %% [markdown]
# Using `if` and `if-else` statements, the computer is able to make informed decisions based on code. As it evaluates the statements from top to bottom, it skips any indented code whenever a conditional expression isn't met.
#
# **This is control flow.** The code is controlling how the program reads and executes code. Anytime we want a program to decide what to do, we write conditional statements.
